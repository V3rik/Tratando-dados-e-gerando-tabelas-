# %%
# trabalhando dados

# %%
#comando de instalação da biblioteca pandas
# !pip install pandas

# %%
# display(tb_gerente)
# display(tb_loja)
# display(tb_produto)

# %%
#importando biblioteca

import pandas as pd


#importando base de dados:
tb_gerente = pd.read_csv("identifica_gerente.csv", sep=";")
tb_loja = pd.read_csv("identifica_loja.csv", sep=";")
tb_produto = pd.read_excel("identifica_produto.xlsx")
                
    
    
                # alterando nome da coluna quantidade para quantidade_vendida
tb_produto = tb_produto.rename(columns={'quantidade':'quantidade_vendida'})


                # criando nova coluna dentro da tabela tb_produts
                #tabela['coluna_nova'] = ? 
tb_produto['total em vendas'] = 0



#multiplicando coluna valor x quantidade vendida
tb_produto['total em vendas'] = tb_produto['valor'] * tb_produto['quantidade_vendida']



print('nome da coluna alterado')
print('Coluna total vendas adicionada')
print('calculo de multiplicação feito')

#exibir dados
#display(tb_gerente)
#display(tb_loja)
#display(tb_produto)






                                                    #mesclar tabelas


tb_gerente = tb_gerente.merge(tb_loja, on='id')
tb_gerente = tb_gerente.merge(tb_produto, on='id')





display(tb_gerente)
# Out:
# nome da coluna alterado
# Coluna total vendas adicionada
# calculo de multiplicação feito
#     id    gerente                   email         loja       cidade  \
# 0    1  Guilherme  forcecell954@gmail.com   americanas      barueri
# 1    1  Guilherme  forcecell954@gmail.com   americanas      barueri
# 2    1  Guilherme  forcecell954@gmail.com   americanas      barueri
# 3    2      Paulo         paulo@gmail.com  casas bahia    guarulhos
# 4    2      Paulo         paulo@gmail.com  casas bahia    guarulhos
# 5    3  Alexandro     alexandro@gmail.com      ragazzo  carapicuiba
# 6    3  Alexandro     alexandro@gmail.com      ragazzo  carapicuiba
# 7    4    Nicolas       Nicolas@gmail.com    riachuelo      barueri
# 8    6     Marina        Marina@gmail.com       renner      jandira
# 9    7     Marcio        Marcio@gmail.com         avan       osasco
# 10   7     Marcio        Marcio@gmail.com         avan       osasco
# 11   8      Maria         Maria@gmail.com          big      itapevi
# 12   9  Cleverson     Cleverson@gmail.com     mcdonals    guarulhos
# 13   9  Cleverson     Cleverson@gmail.com     mcdonals    guarulhos
# 14   9  Cleverson     Cleverson@gmail.com     mcdonals    guarulhos
#
#             produto   valor  quantidade_vendida  total em vendas
# 0             tenis   80.00                   1            80.00
# 1              saia   18.00                   1            18.00
# 2       calça jeans   75.00                   1            75.00
# 3         hamburger   13.99                   2            27.98
# 4              suco    3.00                   2             6.00
# 5          salgados    2.99                   1             2.99
# 6           coxinha    5.00                   6            30.00
# 7            oculos   25.00                   3            75.00
# 8             blusa   20.00                   5           100.00
# 9           jaqueta  150.00                   1           150.00
# 10  prancha de surf  199.99                   2           399.98
# 11    calça moletom  100.00                   2           200.00
# 12             boné   47.00                   2            94.00
# 13             meia    5.00                   5            25.00
# 14           cinto    13.00                   2            26.00

# %%
                                                #contagem de vendas por id:
#conta quantas vezes apareceram o mesmo id 
print('vendas por loja')
contar_vendas = tb_gerente['id'].value_counts()
print(contar_vendas)
# Out:
# vendas por loja
# 1    3
# 9    3
# 2    2
# 3    2
# 7    2
# 4    1
# 6    1
# 8    1
# Name: id, dtype: int64

# %%
                                                #somar todas as vendas
    
somar_vendas_por_id = tb_gerente['total em vendas'].sum()
print('total em vendas foi de: ', somar_vendas_por_id)
# Out:
# total em vendas foi de:  1309.95

# %%
                #somando quantidade de vendas
print('total vendido por loja(id)')
tb_gerente = tb_gerente.groupby("id").sum()
print(tb_gerente)
# Out:
# total vendido por loja(id)
#      valor  quantidade_vendida  total em vendas
# id
# 1   173.00                   3           173.00
# 2    16.99                   4            33.98
# 3     7.99                   7            32.99
# 4    25.00                   3            75.00
# 6    20.00                   5           100.00
# 7   349.99                   3           549.98
# 8   100.00                   2           200.00
# 9    65.00                   9           145.00

# %% [markdown]
# # Exportando dataframe em csv

# %%
tb_gerente.to_csv("tabela-gerada-pelo-python.csv", sep=";")

# %% [markdown]
# tabela exportada em csv:

# %% [markdown]
# ![antes.png](attachment:antes.png)

# %% [markdown]
# Tabela final

# %% [markdown]
# ![depois.jpeg](attachment:depois.jpeg)
